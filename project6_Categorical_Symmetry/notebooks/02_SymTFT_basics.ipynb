# %% [markdown]
# # SymTFT基础
#
# 对称性拓扑场论（SymTFT）将d维理论的对称性编码为(d+1)维拓扑场论。
#
# ## 核心思想
#
# ```
# (d+1)D SymTFT
#     │
#  boundary
#     │
#  d-dim Theory
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
print("SymTFT将对称性提升到高一维！")
print("不同边界条件 → 不同物理理论")
